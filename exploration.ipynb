# %% [markdown]
# ### Import des librairies utiles pour ce projet

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import plotly.express as px
import statsmodels.api as sm

# %% [markdown]
# ### Chargement du dataset selon les csv remis lors de la mission

# %%
clients = pd.read_csv(r'..\projet9_Lapage\data\raw\customers.csv')
produits = pd.read_csv(r'..\projet9_Lapage\data\raw\products.csv')
transactions = pd.read_csv(r'..\projet9_Lapage\data\raw\Transactions.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 clients = pd.read_csv(r'..\projet9_Lapage\data\raw\customers.csv')
#       2 produits = pd.read_csv(r'..\projet9_Lapage\data\raw\products.csv')
#       3 transactions = pd.read_csv(r'..\projet9_Lapage\data\raw\Transactions.csv')
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ### Dimensionnement du dataset

# %%
clients.info()
